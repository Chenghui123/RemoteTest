# %%
import numpy

# %%
dataSet=[[1,1],[3,4],[5,6]]
[example[1] for example in dataSet]
# Out:
# [1, 4, 6]

# %%
array = [1,1,3,1,34,1]
array.count(array[0])
# Out:
# 4

# %%
from matplotlib.pyplot import *
from numpy import *
plot([10,20,30,40,50],[1,2,3,4,6])

# %%
plot([4,3,2,1],'r')

# %%
plot([4,3,2,1],'g')

# %%
plot([4,3,2,1],'g')
plot([1,2,3,4],'r')

# %%
plot([4,3,2,1],'c')

# %%
plot([4,3,2,1],'g--')

# %%
plot([4,3,2,1],'g:')

# %%
plot([4,3,2,1],'g-')

# %%
plot([4,3,2,1],'g.')

# %%
plot([4,3,2,1],'gx-')

# %%
plot([4,3,2,1],'gd--')

# %%
t = arange(0.0, 5.2, 0.2)
plot(t,t,"b^",t,t**2,"gd--",t,t**3,"rx--")
# Out:
# [<matplotlib.lines.Line2D at 0x7f5e9cfe64e0>,
#  <matplotlib.lines.Line2D at 0x7f5e9cfe6630>,
#  <matplotlib.lines.Line2D at 0x7f5e9cfe6e80>]

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title('Using hyphen instead of Unicode minus')
plt.show()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


matplotlib.rcParams['axes.unicode_minus'] = False
fig, ax = plt.subplots()
ax.plot(10*np.random.randn(100), 10*np.random.randn(100), 'o')
ax.set_title(u'测试中文')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


X = 10*np.random.rand(5, 3)

fig, ax = plt.subplots()
ax.imshow(X, interpolation='nearest')

numrows, numcols = X.shape


def format_coord(x, y):
    col = int(x + 0.5)
    row = int(y + 0.5)
    if col >= 0 and col < numcols and row >= 0 and row < numrows:
        z = X[row, col]
        return 'x=%1.4f, y=%1.4f, z=%1.4f' % (x, y, z)
    else:
        return 'x=%1.4f, y=%1.4f' % (x, y)

ax.format_coord = format_coord
plt.show()
